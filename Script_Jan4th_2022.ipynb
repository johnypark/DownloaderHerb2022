# %%
import pandas as pd

# %%
df_DownList=pd.read_table('herbarium2022-v2_2-limited.tsv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
S_TxNm=set(df_DownList.scientificName)

# %%
set([name for name in S_TxNm if ', 'in name])
# Out:
# {'Abdra aprica (Beadle) Al-Shehbaz, M.Koch & Jordon-Thaden',
#  'Adlumia fungosa (Aiton) Britton, Sterns & Poggenb.',
#  'Aeschynomene virginica (L.) Britton, Sterns & Poggenb.',
#  'Agrostis hyemalis (Walter) Britton, Sterns & Poggenb.',
#  'Allium columbianum (Ownbey & Mingrone) P.M.Peterson, Annable & Rieseberg',
#  'Amelanchier × neglecta Eggl. ex K.R.Cushman, M.B.Burgess, E.T.Doucette & C.S.Campb.',
#  'Andropogon glomeratus (Walter) Britton, Sterns & Poggenb.',
#  'Androsace beringensis (S.Kelso, Jurtzev & D.F.Murray) Cubey',
#  'Arnica acaulis Britton, Sterns & Poggenb.',
#  'Artemisia albicans Sòn.Garcia, Garnatje, McArthur, Pellicer, S.C.Sand',
#  'Artemisia capitata (Nutt.) Sòn.Garcia, Garnatje, McArthur, Pellicer, S.C.Sand',
#  'Artemisia inaequifolia Sòn.Garcia, Garnatje, McArthur, Pellicer, S.C.Sand',
#  'Artemisia nuttallii (Torr. & A.Gray) Mosyakin, L.M.Shultz & G.V.Boiko',
# ...

# %%
import os
[names.split() for names in S_TxNm]
# Out:
# [['Anthoxanthum', 'nitens', '(Weber)', 'Y.Schouten', '&', 'Veldkamp'],
#  ['Carex', 'nervina', 'L.H.Bailey'],
#  ['Asimina', 'triloba', '(L.)', 'Dunal'],
#  ['Aralia', 'bicrenata', 'Wooton', '&', 'Standl.'],
#  ['Polystichum', 'californicum', '(D.C.Eaton)', 'Diels'],
#  ['Carex', 'occidentalis', 'L.H.Bailey'],
#  ['Peperomia', 'tenella', '(Sw.)', 'A.Dietr.'],
#  ['Hieracium', 'robinsonii', '(Zahn)', 'Fernald'],
#  ['Chloris', '×', 'subdolichostachya', 'Müll.Hal.'],
#  ['Spermacoce', 'remota', 'Lam.'],
#  ['Cyperus', 'subsquarrosus', '(Muhl.)', 'Bauters'],
#  ['Erigeron', 'tenellus', 'DC.'],
#  ['Lilium', 'iridollae', 'M.G.Henry'],
#  ['Stachys', 'pilosa', 'Nutt.'],
#  ['Astragalus', 'aretioides', '(M.E.Jones)', 'Barneby'],
#  ['Roystonea', 'oleracea', '(Jacq.)', 'O.F.Cook'],
#  ['Pinus', 'remota', '(Little)', 'D.K.Bailey', '&', 'Hawksw.'],
#  ['Geum', 'macrophyllum', 'Willd.'],
#  ['Collinsonia', 'punctata', 'Elliott'],
#  ['Pectis', 'tenuicaulis', 'Urb.'],
# ...

# %%
os.listdir()
# Out:
# ['downd_hrvrd.sh',
#  'main_pnw.sh',
#  'resizeImage.py',
#  'dl_harv.py',
#  'GendldListFromFolder.py',
#  'CheckHarvDowns.py',
#  'Jan4th_2022_Scripts.ipynb',
#  'Script_Jan4th_2022.ipynb',
#  'CheckDownFolder.py',
#  'UpdateDownList-2022-01-04 16\uf03a00\uf03a34.491766.tsv',
#  'h22-v2_1-limited-pnwherbaria-DownList_Jan4th2022.tsv',
#  'output.txt',
#  'UpdateDownList-2022-01-05-0635.tsv',
#  'dlHosts.txt',
#  'DownloadScript_nStart_nEnd_RefName_dPATH_PATHLogfn.sh',
#  'ControlDownloadScript.sh',
#  'herbarium2022-v2_2_limited.tsv']

# %%
df_DownList=pd.read_table(os.listdir()[-1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import pandas as pd
df_DownList['downloadHost'].value_counts()
# Out:
# sweetgum.nybg.org                    356950
# n2t.net                              178853
# mediaphoto.mnhn.fr                   159136
# data.huh.harvard.edu                 138666
# www.pnwherbaria.org                   74834
# api.idigbio.org                       54636
# cdn.plantatlas.org                    53943
# botanydb.colorado.edu                 43535
# arctos.database.museum                39399
# fm-digital-assets.fieldmuseum.org     36371
# www.tropicos.org                      31409
# swbiodiversity.org                    25999
# prc-symbiota.tacc.utexas.edu          25957
# www.kew.org                           17909
# researcharchive.calacademy.org         3252
# Name: downloadHost, dtype: int64

# %%
df_DownList.query('downloadHost in "api.idigbio.org"').to_csv('h22-v2_2-limited-idigbio.tsv',sep="\t",index=False)

# %%
df_DownList=df_DownList.assign(uniquefileName=lambda x: x['scientificName'].values[0]+"__"+str(x['taxaNumber'].values[0])+"__"+x['collectionCode'].values[0]+".jpg")
cols_to_order=['uniquefileName','herb21PATH']
NewCols=[names for names in df_DownList.columns if names not in cols_to_order]+cols_to_order

# %%
df_DownList[NewCols].to_csv('c:\\Users\\vmlea\\Desktop\\herbarium2022-v2_2_limited.tsv',sep="\t",index=False)

# %%
os.path("c:\\Users\\vmlea\\Desktop")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-08e0dd7fb820> in <module>
# ----> 1 os.path("c:\\Users\\vmlea\\Desktop")
#
# TypeError: 'module' object is not callable

# %%
import os
